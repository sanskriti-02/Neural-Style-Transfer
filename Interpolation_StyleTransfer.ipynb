# %%
# https://github.com/fchollet/deep-learning-with-python-notebooks/blob/master/first_edition/8.3-neural-style-transfer.ipynb

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array
#from scipy.misc import imsave
import numpy as np
from scipy.optimize import fmin_l_bfgs_b
import time
import argparse
import os
import imageio
from IPython.display import Image, display, HTML

from keras.applications import vgg16
from keras import backend as K
import requests

# %%
# !pip install keras==2.4.1

# %%
def preprocess_image(image_path):
    img = load_img(image_path, target_size=(img_nrows, img_ncols))
    img = img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = vgg16.preprocess_input(img)
    return img

# util function to convert a tensor into a valid image


def deprocess_image(x):
    if K.image_data_format() == 'channels_first':
        x = x.reshape((3, img_nrows, img_ncols))
        x = x.transpose((1, 2, 0))
    else:
        x = x.reshape((img_nrows, img_ncols, 3))
    # Remove zero-center by mean pixel
    x[:, :, 0] += 103.939
    x[:, :, 1] += 116.779
    x[:, :, 2] += 123.68
    # 'BGR'->'RGB'
    x = x[:, :, ::-1]
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
base_image_path = '/content/drive/MyDrive/megs.jpeg'
style_reference_image_path_2 = '/content/drive/MyDrive/ms1.jpg'
style_reference_image_path_1 = '/content/drive/MyDrive/ms2.jpg'

# %%
width, height = load_img(base_image_path).size
img_nrows = 400
img_ncols = int(width * img_nrows / height)

total_variation_weight = 1.0
style_weight = 1.0
content_weight = 0.025

iterations = 120
warm_up = 30

result_prefix = 'star_goyen'

# %%
base_image = K.constant(preprocess_image(base_image_path))
style_reference_image_1 = K.constant(preprocess_image(style_reference_image_path_1))
style_reference_image_2 = K.constant(preprocess_image(style_reference_image_path_2))

# this will contain our generated image
if K.image_data_format() == 'channels_first':
    combination_image = K.placeholder((1, 3, img_nrows, img_ncols))
else:
    combination_image = K.placeholder((1, img_nrows, img_ncols, 3))

# combine the 4 images into a single Keras tensor
input_tensor = K.concatenate([base_image,
                              style_reference_image_1,
                              style_reference_image_2,
                              combination_image], axis=0)
input_tensor
# Out:
# WARNING:tensorflow:The following Variables were used in a Lambda layer's call (tf.concat), but are not present in its tracked objects:   <tf.Variable 'Variable:0' shape=(1, 400, 533, 3) dtype=float32>
#   <tf.Variable 'Variable:0' shape=(1, 400, 533, 3) dtype=float32>
#   <tf.Variable 'Variable:0' shape=(1, 400, 533, 3) dtype=float32>. This is a strong indication that the Lambda layer should be rewritten as a subclassed Layer.
# <KerasTensor: shape=(4, 400, 533, 3) dtype=float32 (created by layer 'tf.concat')>

# %%
model = vgg16.VGG16(input_tensor=input_tensor,
                    weights='imagenet', include_top=False)
print('Model loaded.')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 2s 0us/step
# Model loaded.

# %%
outputs_dict = dict([(layer.name, layer.output) for layer in model.layers])

# %%
def gram_matrix(x):
    assert K.ndim(x) == 3
    if K.image_data_format() == 'channels_first':
        features = K.batch_flatten(x)
    else:
        features = K.batch_flatten(K.permute_dimensions(x, (2, 0, 1)))
    gram = K.dot(features, K.transpose(features))
    return gram

def style_loss(style, combination):
    assert K.ndim(style) == 3
    assert K.ndim(combination) == 3
    S = gram_matrix(style)
    C = gram_matrix(combination)
    channels = 3
    size = img_nrows * img_ncols
    return K.sum(K.square(S - C)) / (4. * (channels ** 2) * (size ** 2))

# %%
def content_loss(base, combination):
    return K.sum(K.square(combination - base))

# %%
def content_loss(base, combination):
    return K.sum(K.square(combination - base))

# %%
def total_variation_loss(x):
    assert K.ndim(x) == 4
    if K.image_data_format() == 'channels_first':
        a = K.square(x[:, :, :img_nrows - 1, :img_ncols - 1] - x[:, :, 1:, :img_ncols - 1])
        b = K.square(x[:, :, :img_nrows - 1, :img_ncols - 1] - x[:, :, :img_nrows - 1, 1:])
    else:
        a = K.square(x[:, :img_nrows - 1, :img_ncols - 1, :] - x[:, 1:, :img_ncols - 1, :])
        b = K.square(x[:, :img_nrows - 1, :img_ncols - 1, :] - x[:, :img_nrows - 1, 1:, :])
    return K.sum(K.pow(a + b, 1.25))

# %%
import tensorflow as tf
tf.compat.v1.disable_eager_execution()

loss = K.variable(0.)
layer_features = outputs_dict['block4_conv2']
base_image_features = layer_features[0, :, :, :]
combination_features = layer_features[3, :, :, :]
loss = loss + content_weight * content_loss(base_image_features,
                                      combination_features)
step = K.placeholder()
feature_layers = ['block1_conv1', 'block2_conv1',
                  'block3_conv1', 'block4_conv1',
                  'block5_conv1']
for layer_name in feature_layers:
    layer_features = outputs_dict[layer_name]
    style_reference_features_1 = layer_features[1, :, :, :]
    style_reference_features_2 = layer_features[2, :, :, :]
    combination_features = layer_features[3, :, :, :]
    sl_1 = style_loss(style_reference_features_1, combination_features) * step
    sl_2 = style_loss(style_reference_features_2, combination_features) * (1 - step)
    loss = loss + (style_weight / len(feature_layers)) * (sl_1 + sl_2)
loss = loss + total_variation_weight * total_variation_loss(combination_image)

# get the gradients of the generated image wrt the loss
grads = K.gradients(loss, combination_image)[0]

outputs = [loss]
if isinstance(grads, (list, tuple)):
    outputs = outputs + grads
else:
    outputs.append(grads)

f_outputs = K.function([combination_image, step], outputs)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-18-ce49fb5aa7d9> in <module>
#       4 loss = K.variable(0.)
#       5 layer_features = outputs_dict['block4_conv2']
# ----> 6 base_image_features = layer_features[0, :, :, :]
#       7 combination_features = layer_features[3, :, :, :]
#       8 loss = loss + content_weight * content_loss(base_image_features,
#
# /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
#     155       del filtered_tb
#
# /usr/local/lib/python3.8/dist-packages/keras/layers/core/tf_op_layer.py in handle(self, args, kwargs)
#     568             for x in tf.nest.flatten([args, kwargs])
#     569         ):
# --> 570             return SlicingOpLambda(self.op)(*args, **kwargs)
#     571         else:
#     572             return self.NOT_SUPPORTED
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/base_layer_v1.py in __call__(self, *args, **kwargs)
#     896                         self._compute_dtype_object
#     897                     ):
# --> 898                         outputs = self.call(cast_inputs, *args, **kwargs)
#     899                     self._handle_activity_regularization(inputs, outputs)
#     900                     self._set_mask_metadata(inputs, outputs, input_masks)
#
# /usr/local/lib/python3.8/dist-packages/keras/layers/core/tf_op_layer.py in _call_wrapper(*args, **kwargs)
#     534                 new_kwargs[key] = value
#     535
# --> 536             return original_call(*new_args, **new_kwargs)
#     537
#     538         self.call = tf.__internal__.decorator.make_decorator(
#
# /usr/local/lib/python3.8/dist-packages/keras/layers/core/tf_op_layer.py in _call_wrapper(*args, **kwargs)
#     240         # Decorate the function to produce this layer's call method
#     241         def _call_wrapper(*args, **kwargs):
# --> 242             return self._call_wrapper(*args, **kwargs)
#     243
#     244         self.call = tf.__internal__.decorator.make_decorator(
#
# /usr/local/lib/python3.8/dist-packages/keras/layers/core/tf_op_layer.py in _call_wrapper(self, *args, **kwargs)
#     277             # multiple ops w/ the same name when the layer is reused)
#     278             kwargs.pop("name", None)
# --> 279             result = self.function(*args, **kwargs)
#     280         self._check_variables(created_variables, tape.watched_variables())
#     281         return result
#
# ... last 5 frames repeated, from the frame below ...
#
# /usr/local/lib/python3.8/dist-packages/keras/layers/core/tf_op_layer.py in handle(self, args, kwargs)
#     568             for x in tf.nest.flatten([args, kwargs])
#     569         ):
# --> 570             return SlicingOpLambda(self.op)(*args, **kwargs)
#     571         else:
#     572             return self.NOT_SUPPORTED
#
# RecursionError: maximum recursion depth exceeded while getting the str of an object

# %%
def eval_loss_and_grads(x, perc):
    if K.image_data_format() == 'channels_first':
        x = x.reshape((1, 3, img_nrows, img_ncols))
    else:
        x = x.reshape((1, img_nrows, img_ncols, 3))
    outs = f_outputs([x, perc])
    loss_value = outs[0]
    if len(outs[1:]) == 1:
        grad_values = outs[1].flatten().astype('float64')
    else:
        grad_values = np.array(outs[1:]).flatten().astype('float64')
    return loss_value, grad_values

class Evaluator(object):

    def __init__(self):
        self.loss_value = None
        self.grads_values = None
        self.perc = 0

    def loss(self, x):
        assert self.loss_value is None
        loss_value, grad_values = eval_loss_and_grads(x, self.perc)
        self.loss_value = loss_value
        self.grad_values = grad_values
        return self.loss_value

    def grads(self, x):
        assert self.loss_value is not None
        grad_values = np.copy(self.grad_values)
        self.loss_value = None
        self.grad_values = None
        return grad_values

evaluator = Evaluator()

# %%
if K.image_data_format() == 'channels_first':
    x = np.random.uniform(0, 255, (1, 3, img_nrows, img_ncols)) - 128.
else:
    x = np.random.uniform(0, 255, (1, img_nrows, img_ncols, 3)) - 128.

iterations = 2000

from tensorflow.keras.preprocessing.image import save_img
IMAGE_BASE = '/content/drive/MyDrive/'

frames = []
for i in range(0, iterations):
    start_time = time.time()
    if i > warm_up:
        frames.append(fname)
        evaluator.perc = float(i - warm_up) / (iterations - warm_up - 1)
    else:
        evaluator.perc = 0
    print('Start of iteration', i, evaluator.perc)
    x, min_val, info = fmin_l_bfgs_b(evaluator.loss, x.flatten(),
                                     fprime=evaluator.grads, maxfun=20)
    print('Current loss value:', min_val)
    # save current generated image
    img = deprocess_image(x.copy())
    if i == 10:
      fname = IMAGE_BASE + result_prefix + '_at_iteration_%d.png' % i
      save_img(fname, img)
      print('Image saved as', fname)
    end_time = time.time()
    print('Iteration %d completed in %ds' % (i, end_time - start_time))
# Out:
# Start of iteration 0 0
# Current loss value: 11076406000.0
# Image saved as /content/drive/MyDrive/star_goyen_at_iteration_0.png
# Iteration 0 completed in 8s
# Start of iteration 1 0
# Current loss value: 6602123300.0
# Image saved as /content/drive/MyDrive/star_goyen_at_iteration_1.png
# Iteration 1 completed in 8s
# Start of iteration 2 0
# Current loss value: 5137502000.0
# Image saved as /content/drive/MyDrive/star_goyen_at_iteration_2.png
# Iteration 2 completed in 8s
# Start of iteration 3 0
# Current loss value: 4277049000.0
# Image saved as /content/drive/MyDrive/star_goyen_at_iteration_3.png
# Iteration 3 completed in 8s
# Start of iteration 4 0
# Current loss value: 3741511700.0
# Image saved as /content/drive/MyDrive/star_goyen_at_iteration_4.png
# Iteration 4 completed in 8s
# Start of iteration 5 0
# Current loss value: 3366357500.0
# Image saved as /content/drive/MyDrive/star_goyen_at_iteration_5.png
# Iteration 5 completed in 9s
# Start of iteration 6 0
# Current loss value: 3109533200.0
# Image saved as /content/drive/MyDrive/star_goyen_at_iteration_6.png
# Iteration 6 completed in 10s
# Start of iteration 7 0
# Current loss value: 2922517000.0
# Image saved as /content/drive/MyDrive/star_goyen_at_iteration_7.png
# Iteration 7 completed in 8s
# Start of iteration 8 0
# Current loss value: 2796249300.0
# Image saved as /content/drive/MyDrive/star_goyen_at_iteration_8.png
# Iteration 8 completed in 9s
# Start of iteration 9 0
# Current loss value: 2699007000.0
# Image saved as /content/drive/MyDrive/star_goyen_at_iteration_9.png
# Iteration 9 completed in 8s
# Start of iteration 10 0
# Current loss value: 2624930600.0
# Image saved as /content/drive/MyDrive/star_goyen_at_iteration
.0
# Image saved as /content/drive/MyDrive/star_goyen_at_iteration_573.png
# Iteration 573 completed in 9s
# Start of iteration 574 0.9560632688927944
# Current loss value: 1869459700.0
# Image saved as /content/drive/MyDrive/star_goyen_at_iteration_574.png
# Iteration 574 completed in 8s
# Start of iteration 575 0.9578207381370826
# Current loss value: 1836302600.0
# Image saved as /content/drive/MyDrive/star_goyen_at_iteration_575.png
# Iteration 575 completed in 9s
# Start of iteration 576 0.9595782073813708
# Current loss value: 1803032800.0
# Image saved as /content/drive/MyDrive/star_goyen_at_iteration_576.png
# Iteration 576 completed in 9s
# Start of iteration 577 0.961335676625659
# Current loss value: 1769647000.0
# Image saved as /content/drive/MyDrive/star_goyen_at_iteration_577.png
# Iteration 577 completed in 8s
# Start of iteration 578 0.9630931458699473
# Current loss value: 1736148000.0
# Image saved as /content/drive/MyDrive/star_goyen_at_iteration_578.png
# Iteration 578 completed in 9s
# Start of iteration 579 0.9648506151142355
# Current loss value: 1702543900.0
# Image saved as /content/drive/MyDrive/star_goyen_at_iteration_579.png
# Iteration 579 completed in 9s
# Start of iteration 580 0.9666080843585237
# Current loss value: 1668811300.0
# Image saved as /content/drive/MyDrive/star_goyen_at_iteration_580.png
# Iteration 580 completed in 8s
# Start of iteration 581 0.968365553602812
# Current loss value: 1634963500.0
# Image saved as /content/drive/MyDrive/star_goyen_at_iteration_581.png
# Iteration 581 completed in 9s
# Start of iteration 582 0.9701230228471002
# Current loss value: 1600993700.0
# Image saved as /content/drive/MyDrive/star_goyen_at_iteration_582.png
# Iteration 582 completed in 9s
# Start of iteration 583 0.9718804920913884
# Current loss value: 1566903400.0
# Image saved as /content/drive/MyDrive/star_goyen_at_iteration_583.png
# Iteration 583 completed in 8s
# Start of iteration 584 0.9736379613356766
# Current loss value: 1532721300.0
# Image saved as /content/drive/MyDrive/star_goyen_at_iteration_584.png
# Iteration 584 completed in 9s
# Start of iteration 585 0.9753954305799648
# Current loss value: 1498438700.0
# Image saved as /content/drive/MyDrive/star_goyen_at_iteration_585.png
# Iteration 585 completed in 9s
# Start of iteration 586 0.9771528998242531
# Current loss value: 1464039700.0
# Image saved as /content/drive/MyDrive/star_goyen_at_iteration_586.png
# Iteration 586 completed in 8s
# Start of iteration 587 0.9789103690685413
# Current loss value: 1429530200.0
# Image saved as /content/drive/MyDrive/star_goyen_at_iteration_587.png
# Iteration 587 completed in 9s
# Start of iteration 588 0.9806678383128296
# Current loss value: 1394878500.0
# Image saved as /content/drive/MyDrive/star_goyen_at_iteration_588.png
# Iteration 588 completed in 9s
# Start of iteration 589 0.9824253075571178
# Current loss value: 1360070700.0
# Image saved as /content/drive/MyDrive/star_goyen_at_iteration_589.png
# Iteration 589 completed in 8s
# Start of iteration 590 0.984182776801406
# Current loss value: 1325121000.0
# Image saved as /content/drive/MyDrive/star_goyen_at_iteration_590.png
# Iteration 590 completed in 9s
# Start of iteration 591 0.9859402460456942
# Current loss value: 1290066000.0
# Image saved as /content/drive/MyDrive/star_goyen_at_iteration_591.png
# Iteration 591 completed in 9s
# Start of iteration 592 0.9876977152899824
# Current loss value: 1254903000.0
# Image saved as /content/drive/MyDrive/star_goyen_at_iteration_592.png
# Iteration 592 completed in 8s
# Start of iteration 593 0.9894551845342706
# Current loss value: 1219647200.0
# Image saved as /content/drive/MyDrive/star_goyen_at_iteration_593.png
# Iteration 593 completed in 9s
# Start of iteration 594 0.9912126537785588
# Current loss value: 1184306200.0
# Image saved as /content/drive/MyDrive/star_goyen_at_iteration_594.png
# Iteration 594 completed in 9s
# Start of iteration 595 0.9929701230228472
# Current loss value: 1148860300.0
# Image saved as /content/drive/MyDrive/star_goyen_at_iteration_595.png
# Iteration 595 completed in 8s
# Start of iteration 596 0.9947275922671354
# Current loss value: 1113308000.0
# Image saved as /content/drive/MyDrive/star_goyen_at_iteration_596.png
# Iteration 596 completed in 9s
# Start of iteration 597 0.9964850615114236
# Current loss value: 1077649000.0
# Image saved as /content/drive/MyDrive/star_goyen_at_iteration_597.png
# Iteration 597 completed in 9s
# Start of iteration 598 0.9982425307557118
# Current loss value: 1041850500.0
# Image saved as /content/drive/MyDrive/star_goyen_at_iteration_598.png
# Iteration 598 completed in 8s
# Start of iteration 599 1.0
# Current loss value: 1005898500.0
# Image saved as /content/drive/MyDrive/star_goyen_at_iteration_599.png
# Iteration 599 completed in 8s

# %%
cycled = frames + list(reversed(frames[1:-1]))
# Save them as frames into a gif 
kargs = { 'duration': 0.1 }
imageio.mimsave(IMAGE_BASE + 'animated1.gif', [imageio.imread(x) for x in cycled], 'GIF', **kargs)

HTML('<img src="%s">' % (IMAGE_BASE + 'animated.gif'))
# Out:
# <img src="/content/drive/MyDrive/animated.gif">
